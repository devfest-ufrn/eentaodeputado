# %%
# -*- coding: UTF-8 -*-
import numpy as np
import pandas as pd
import requests as req

# %%
CONFIG = {
    'dep': '../data/deputados-detalhes.csv',
    'prop': '../data/proposicoes.csv'
}

# %%
deputados_df = pd.read_csv(CONFIG['dep'])
proposicoes_df = pd.read_csv(CONFIG['prop'])

# %%
deputados_df.head()
# Out:
#    anexo codOrcamento condicao                              email       fone  \
# 0      4         3283  Titular          dep.goulart@camara.gov.br  3215-5533
# 1      4         2152  Titular         dep.betofaro@camara.gov.br  3215-5723
# 2      4         2488  Titular  dep.rodrigodecastro@camara.gov.br  3215-5701
# 3      4         2551  Titular      dep.laertebessa@camara.gov.br  3215-5340
# 4      3         3712  Titular     dep.majorolimpio@camara.gov.br  3215-5279
#
#    gabinete  idParlamentar  ideCadastro  matricula  \
# 0       533        5830382       178980        361
# 1       723        5830714       141335         19
# 2       701        5830453       141531        268
# 3       340        5830785       141478        412
# 4       279        5830405       178826        368
#
#                          nome    nomeParlamentar partido       sexo  uf  \
# 0    ANTONIO GOULART DOS REIS            GOULART     PSD  masculino  SP
# 1  JOSÉ ROBERTO OLIVEIRA FARO          BETO FARO      PT  masculino  PA
# 2   RODRIGO BATISTA DE CASTRO  RODRIGO DE CASTRO    PSDB  masculino  MG
# 3   LAERTE RODRIGUES DE BESSA       LAERTE BESSA      PR  masculino  DF
# 4        SERGIO OLIMPIO GOMES      MAJOR OLIMPIO     PDT  masculino  SP
#
#                                              urlFoto
# 0  http://www.camara.gov.br/internet/deputado/ban...
# 1  http://www.camara.gov.br/internet/deputado/ban...
# 2  http://www.camara.gov.br/internet/deputado/ban...
# 3  http://www.camara.gov.br/internet/deputado/ban...
# 4  http://www.camara.gov.br/internet/deputado/ban...

# %%
proposicoes_df.head()
# Out:
#   tipo  numero   ano                nome_proposicao  id_proposicao  \
# 0  REQ    1030  2015   REQ 1030/2015 => PL 644/2015        1049075
# 1  REQ    1041  2015  REQ 1041/2015 => PL 6232/2013        1049167
# 2   PL     846  2015                    PL 846/2015        1049380
# 3  MPV     671  2015                   MPV 671/2015        1050558
# 4   PL     863  2015                    PL 863/2015        1050643
#
#    id_proposicao_principal nome_proposicao_origem  \
# 0                 994678.0                    NaN
# 1                 589924.0                    NaN
# 2                      NaN                    NaN
# 3                      NaN                    NaN
# 4                      NaN                    NaN
#
#                                tipo_proposicao  \
# 0  Requerimento de Urgência (Art. 155 do RICD)
# 1  Requerimento de Urgência (Art. 155 do RICD)
# 2                               Projeto de Lei
# 3                            Medida Provisória
# 4                               Projeto de Lei
#
#                                tema  \
# 0                               NaN
# 1                               NaN
# 2  Direito Penal e Processual Penal
# 3      Desporto e Lazer; Tributação
# 4                        Tributação
#
#                                               ementa    ...    partido_autor  \
# 0  Com base no art. 155 do Regimento Interno, req...    ...               PP
# 1  Requeremos a Vossa Excelência, nos termos do a...    ...             PMDB
# 2  Acrescenta parágrafo ao artigo 121 do Decreto-...    ...             PMDB
# 3  Institui o Programa de Modernização da Gestão ...    ...              NaN
# 4  Altera a Lei nº 12.546, de 14 de dezembro de 2...    ...              NaN
#
#   data_apresentacao       regime_tramitacao data_ultimo_despacho  \
# 0        18/03/2015                       .                  NaN
# 1        18/03/2015                       .                  NaN
# 2        19/03/2015  Urgência art. 155 RICD           19/03/2015
# 3        20/03/2015                Urgência           01/07/2015
# 4        20/03/2015     Urgência art. 64 CF           13/05/2015
#
#                                      ultimo_despacho  \
# 0                                                NaN
# 1                                                NaN
# 2  Apense-se à(ao) PL-3131/2008. Proposição Sujei...
# 3             Ao Plenário para leitura. Publique-se.
# 4  Revejo o despacho de deferimento proferido no ...
#
#                                     apreciacao  \
# 0                                            .
# 1                                            .
# 2  Proposição Sujeita à Apreciação do Plenário
# 3  Proposição Sujeita à Apreciação do Plenário
# 4  Proposição Sujeita à Apreciação do Plenário
#
#                                            indexacao  \
# 0                                                NaN
# 1                                                NaN
# 2  Alteração, Código Penal, agravação penal, homi...
# 3  Alteração, Estatuto de Defesa do Torcedor, Lei...
# 4  Alteração, Lei do Bem, contribuição previdenci...
#
#                                        situacao  \
# 0  MESA - Tramitação do Requerimento Finalizada
# 1        COAPP(SGM) - Aguardando Encaminhamento
# 2    Tranformada no(a) Lei Ordinária 13142/2015
# 3    Tranformada no(a) Lei Ordinária 13155/2015
# 4    Tranformada no(a) Lei Ordinária 13161/2015
#
#                                    link_inteiro_teor apensadas
# 0  http://www.camara.gov.br/proposicoesWeb/prop_m...       NaN
# 1  http://www.camara.gov.br/proposicoesWeb/prop_m...       NaN
# 2  http://www.camara.gov.br/proposicoesWeb/prop_m...       NaN
# 3  http://www.camara.gov.br/proposicoesWeb/prop_m...       NaN
# 4  http://www.camara.gov.br/proposicoesWeb/prop_m...       NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Cruzando as duas tabelas
#
# Vamos identificar se existe algum tipo de relação entre as duas tabelas(id do deputado, nome, ou algo do tipo)

# %%
from unicodedata import normalize
def remover_acentos(txt, codif='utf-8'):
    return normalize('NFKD', txt.decode(codif)).encode('ASCII','ignore')

# %%
proposicoes_df.columns
# Out:
# Index([u'tipo', u'numero', u'ano', u'nome_proposicao', u'id_proposicao',
#        u'id_proposicao_principal', u'nome_proposicao_origem',
#        u'tipo_proposicao', u'tema', u'ementa', u'explicacao_ementa', u'autor',
#        u'ide_cadastro', u'uf_autor', u'partido_autor', u'data_apresentacao',
#        u'regime_tramitacao', u'data_ultimo_despacho', u'ultimo_despacho',
#        u'apreciacao', u'indexacao', u'situacao', u'link_inteiro_teor',
#        u'apensadas'],
#       dtype='object')

# %%
proposicoes_df['autor'].head(10)
# Out:
# 0     Eduardo da Fonte
# 1    Leonardo Picciani
# 2    Leonardo Picciani
# 3      Poder Executivo
# 4      Poder Executivo
# 5    Leonardo Picciani
# 6       Mendonça Filho
# 7     Celso Russomanno
# 8     Eduardo da Fonte
# 9     Eduardo da Fonte
# Name: autor, dtype: object

# %%
deputados_df.columns
# Out:
# Index([u'anexo', u'codOrcamento', u'condicao', u'email', u'fone', u'gabinete',
#        u'idParlamentar', u'ideCadastro', u'matricula', u'nome',
#        u'nomeParlamentar', u'partido', u'sexo', u'uf', u'urlFoto'],
#       dtype='object')

# %%
deputados_df.head()
# Out:
#    anexo codOrcamento condicao                              email       fone  \
# 0      4         3283  Titular          dep.goulart@camara.gov.br  3215-5533
# 1      4         2152  Titular         dep.betofaro@camara.gov.br  3215-5723
# 2      4         2488  Titular  dep.rodrigodecastro@camara.gov.br  3215-5701
# 3      4         2551  Titular      dep.laertebessa@camara.gov.br  3215-5340
# 4      3         3712  Titular     dep.majorolimpio@camara.gov.br  3215-5279
#
#    gabinete  idParlamentar  ideCadastro  matricula  \
# 0       533        5830382       178980        361
# 1       723        5830714       141335         19
# 2       701        5830453       141531        268
# 3       340        5830785       141478        412
# 4       279        5830405       178826        368
#
#                          nome    nomeParlamentar partido       sexo  uf  \
# 0    ANTONIO GOULART DOS REIS            GOULART     PSD  masculino  SP
# 1  JOSÉ ROBERTO OLIVEIRA FARO          BETO FARO      PT  masculino  PA
# 2   RODRIGO BATISTA DE CASTRO  RODRIGO DE CASTRO    PSDB  masculino  MG
# 3   LAERTE RODRIGUES DE BESSA       LAERTE BESSA      PR  masculino  DF
# 4        SERGIO OLIMPIO GOMES      MAJOR OLIMPIO     PDT  masculino  SP
#
#                                              urlFoto
# 0  http://www.camara.gov.br/internet/deputado/ban...
# 1  http://www.camara.gov.br/internet/deputado/ban...
# 2  http://www.camara.gov.br/internet/deputado/ban...
# 3  http://www.camara.gov.br/internet/deputado/ban...
# 4  http://www.camara.gov.br/internet/deputado/ban...

# %% [markdown]
# ## Encontramos uma relação!
# > O nome do autor no campo *autor* na tabela **proposicoes** se colocado no modo *uppercase* corresponde ao campo *nomeParlamentar* na tabela **deputados**, se o mesmo não estiver, é pq o referido deputado não está mais em exercício.

# %%
autor_proposicao = proposicoes_df.iloc[7]['autor']

condicao = deputados_df['nomeParlamentar'] == autor_proposicao.upper()
deputados_df[condicao]
# Out:
#      anexo codOrcamento condicao                              email  \
# 471      4         3160  Titular  dep.celsorussomanno@camara.gov.br
#
#           fone  gabinete  idParlamentar  ideCadastro  matricula  \
# 471  3215-5960       960        5830790        73441        347
#
#                            nome   nomeParlamentar partido       sexo  uf  \
# 471  CELSO UBIRAJARA RUSSOMANNO  CELSO RUSSOMANNO     PRB  masculino  SP
#
#                                                urlFoto
# 471  http://www.camara.gov.br/internet/deputado/ban...

# %%
def formatar_nome(txt):
    result = []
    for t in txt.split():
            if len(t) > 2:           
                result.append()


def attach_deputados_to_proposicoes():
    nome_parlamentar_normalizado = []
    
    for nomes in deputados_df['nomeParlamentar']:
        nome_parlamentar_normalizado.append(remover_acentos(nomes))
    
    return [x.lower() for x in nome_parlamentar_normalizado]

# %%
attach_deputados_to_proposicoes()
# Out:
# ['goulart',
#  'beto faro',
#  'rodrigo de castro',
#  'laerte bessa',
#  'major olimpio',
#  'luis tibe',
#  'aliel machado',
#  'ivan valente',
#  'pedro chaves',
#  'assis carvalho',
#  'betinho gomes',
#  'carlos henrique gaguim',
#  'luiz carlos ramos ',
#  'josi nunes',
#  'alfredo kaefer',
#  'ricardo tripoli',
#  'felipe maia',
#  'leopoldo meyer',
#  'marinaldo rosendo',
#  'nelson marquezelli',
#  'domingos savio',
#  'raquel muniz',
#  'fabio garcia',
#  'vicentinho junior',
#  'andre fufuca',
#  'leo de brito',
#  'anderson ferreira',
#  'aguinaldo ribeiro',
#  'evandro roman',
#  'decio lima',
#  'afonso florence',
#  'rosangela gomes',
#  'celso maldaner',
#  'marcus vicente',
#  'adelson barreto',
#  'vinicius carvalho',
#  'antonio imbassahy',
#  'giuseppe vecci',
#  'jean wyllys',
#  'roberto britto',
#  'sergio zveiter',
#  'walter alves',
#  'altineu cortes',
#  'joao daniel',
#  'jony marcos',
#  'marcon',
#  'dilceu sperafico',
#  'ezequiel fonseca',
#  'takayama',
#  'antonio bulhoes',
#  'indio da costa',
#  'vicentinho',
#  'augusto carvalho',
#  'marcos abrao',
#  'vinicius gurgel',
#  'caca leao',
#  'geovania de sa',
#  'lazaro botelho',
#  'arthur oliveira maia',
#  'sergio vidigal',
#  'rocha',
#  'leonardo picciani',
#  'eduardo barbosa',
#  'jefferson campos',
#  'ronaldo fonseca',
#  'danilo forte',
#  'afonso motta',
#  'waldenor pereira',
#  'atila lins',
#  'remidio monai',
#  'bruna furlan',
#  'fernando jordao',
#  'roney nemer',
#  'moroni torgan',
#  'carlos andrade',
#  'pr. marco feliciano',
#  'celso pansera',
#  'julio cesar',
#  'ricardo izar',
#  'tadeu alencar',
#  'joaquim passarinho',
#  'leonardo monteiro',
#  'valtenir pereira',
#  'cesar halum',
#  'aluisio mendes',
#  'roberto balestra',
#  'edmar arruda',
#  'maria helena',
#  'efraim filho',
#  'damina pereira',
#  'carlos sampaio',
#  'joao campos',
#  'laercio oliveira',
#  'cabo daciolo',
#  'jutahy junior',
#  'luiz carlos hauly',
#  'gabriel guimaraes',
#  'helio leite',
#  'cicero almeida',
#  'bacelar',
#  'aureo',
#  'margarida salomao',
#  'waldir maranhao',
#  'macedo',
#  'hissa abrahao',
#  'alexandre baldy',
#  'adilton sachetti',
#  'delegado waldir',
#  'daniel coelho',
#  'alfredo nascimento',
#  'carlos bezerra',
#  'osmar serraglio',
#  'mauro mariani',
#  'alexandre valle',
#  'dagoberto',
#  'alex manente',
#  'jose carlos aleluia',
#  'marx beltrao ',
#  'marco maia',
#  'rubens otoni',
#  'celio silveira',
#  'paulo maluf',
#  'beto rosado',
#  'lindomar garcon',
#  'dulce miranda',
#  'mandetta',
#  'ezequiel teixeira',
#  'luiza erundina',
#  'ricardo barros',
#  'alceu moreira',
#  'roberto goes',
#  'elmar nascimento',
#  'paulo feijo',
#  'wladimir costa',
#  'anibal gomes',
#  'professora marcivania',
#  'jose guimaraes',
#  'nelson marchezan junior',
#  'beto mansur',
#  'julio delgado',
#  'ronaldo carletto',
#  'evandro gussi',
#  'marcio alvino',
#  'julio lopes',
#  'andre figueiredo',
#  'sergio reis',
#  'milton monti',
#  'giovani cherini',
#  'paulo foletto',
#  'jaime martins',
#  'osmar terra',
#  'givaldo vieira',
#  'sarney filho',
#  'jose carlos araujo',
#  'gilberto nascimento',
#  'soraya santos',
#  'benedita da silva',
#  'simone morgado',
#  'toninho wandscheer',
#  'nilto tatto',
#  'daniel almeida',
#  'fabio reis',
#  'juscelino filho',
#  'ronaldo nogueira',
#  'carlos gomes',
#  'pastor franklin',
#  'hugo leal',
#  'antonio brito',
#  'geraldo resende',
#  'carlos zarattini',
#  'sheridan',
#  'josue bengtson',
#  'rafael motta',
#  'paulo pereira da silva',
#  'paulo freire',
#  'dimas fabiano',
#  'esperidiao amin',
#  'alan rick',
#  'domingos neto',
#  'jo moraes',
#  'nilson leitao',
#  'wolney queiroz',
#  'arnaldo jordy',
#  'jose priante',
#  'simao sessim',
#  'heuler cruvinel',
#  'orlando silva',
#  'luciana santos',
#  'marcelo belinati',
#  'misael varella',
#  'roberto alves',
#  'pedro cunha lima',
#  'padre joao',
#  'sergio moraes',
#  'iracema portella',
#  'jose airton cirilo',
#  'lucio vieira lima',
#  'marcelo matos',
#  'jeronimo goergen',
#  'heraclito fortes',
#  'genecias noronha',
#  'luciano ducci',
#  'ricardo teobaldo ',
#  'jorginho mello',
#  'valmir prascidelli',
#  'joao gualberto',
#  'jose nunes',
#  'zeca dirceu',
#  'mariana carvalho',
#  'tiririca',
#  'diego andrade',
#  'marcos reategui',
#  'afonso hamm',
#  'silas camara',
#  'zeca do pt',
#  'victor mendes',
#  'abel mesquita jr.',
#  'alice portugal',
#  'rogerio rosso',
#  'paulo abi-ackel',
#  'jandira feghali',
#  'deley',
#  'jovair arantes',
#  'veneziano vital do rego',
#  'eduardo bolsonaro',
#  'luiz fernando faria',
#  'cristiane brasil',
#  'herculano passos',
#  'rodrigo pacheco',
#  'arthur virgilio bisneto',
#  "chico d'angelo",
#  'chico alencar',
#  'arthur lira',
#  'romulo gouveia',
#  'leandre',
#  'nilson pinto',
#  'mara gabrilli',
#  'bilac pinto',
#  'joao rodrigues',
#  'odelmo leao',
#  'luis carlos heinze',
#  'jorge tadeu mudalen',
#  'jhonatan de jesus',
#  'uldurico junior',
#  'laudivio carvalho',
#  'carlos manato',
#  'angelim',
#  'pompeo de mattos',
#  'eduardo cunha',
#  'erivelton santana',
#  'pedro fernandes',
#  'missionario jose olimpio',
#  'marcelo aro',
#  'moses rodrigues',
#  'giacobo',
#  'alexandre leite',
#  'chico lopes',
#  'janete capiberibe',
#  'luizianne lins',
#  'ze silva',
#  'marcelo alvaro antonio',
#  'luiz sergio',
#  'henrique fontana',
#  'flaviano melo',
#  'expedito netto',
#  'carlos melles',
#  'luiz lauro filho',
#  'rubens bueno',
#  'renato molling',
#  'bebeto',
#  'andre abdon',
#  'miguel lombardi',
#  'nilton capixaba',
#  'lucio vale',
#  'edmilson rodrigues',
#  'tenente lucio',
#  'ronaldo benedet',
#  'luiz nishimori',
#  'rodrigo maia',
#  'francisco floriano',
#  'adalberto cavalcanti',
#  'marcelo castro',
#  'claudio cajado',
#  'valmir assuncao',
#  'eli correa filho',
#  'irmao lazaro',
#  'baleia rossi',
#  'hildo rocha',
#  'cabo sabino',
#  'carmen zanotto',
#  'mario heringer',
#  'andre moura',
#  'wellington roberto',
#  'iraja abreu',
#  'julia marinho',
#  'paulao',
#  'odorico monteiro',
#  'sergio souza ',
#  'damiao feliciano',
#  'ana perugini',
#  'nelson meurer',
#  'andres sanchez',
#  'flavinho',
#  'atila lira',
#  'fausto pinato',
#  'antonio jacome',
#  'vicente candido',
#  'subtenente gonzaga',
#  'keiko ota',
#  'lincoln portela',
#  'rodrigo martins',
#  'pastor eurico',
#  'vitor lippi',
#  'arnaldo faria de sa',
#  'silas brasileiro',
#  'wadson ribeiro',
#  'augusto coutinho ',
#  'fernando monteiro ',
#  'carlos eduardo cadoca',
#  'fernando marroni',
#  'walney rocha',
#  'marquinho mendes',
#  'celso jacob',
#  'mauro pereira',
#  'jose fogaca ',
#  'roberto freire',
#  'alberto filho',
#  'mainha',
#  'wadih damous',
#  'penna',
#  'raul jungmann',
#  'fabricio oliveira',
#  'vicente arruda',
#  'antonio carlos mendes thame',
#  'lobbe neto',
#  'davidson magalhaes',
#  'sandes junior',
#  'edinho bez',
#  'walter ihoshi',
#  'ademir camilo',
#  'fernando torres',
#  'pauderney avelino',
#  'elcione barbalho',
#  'helder salomao',
#  'renata abreu',
#  'professor victorio galli',
#  'beto salame',
#  'bruno araujo',
#  'joao carlos bacelar',
#  'marcus pestana',
#  'toninho pinheiro',
#  'christiane de souza yared',
#  'caio narcio',
#  'ronaldo lessa',
#  'reginaldo lopes',
#  'lucio mosquini',
#  'francisco chapadinha',
#  'ronaldo martins',
#  'edio lopes',
#  'joao paulo papa',
#  'marcos montes',
#  'samuel moreira',
#  'marcio marinho',
#  'leonidas cristino',
#  'marcos rotta',
#  'marcelo squassoni',
#  'sandro alex',
#  'paes landim',
#  'valadares filho',
#  'pedro uczai',
#  'jozi araujo',
#  'hiran goncalves',
#  'joao marcelo souza',
#  'paulo pimenta',
#  'jose reinaldo',
#  'covatti filho',
#  'felipe bornier',
#  'dr. sinval malheiros',
#  'jose stedile',
#  'marcos rogerio',
#  'otavio leite',
#  'eduardo da fonte',
#  'adelmo carneiro leao',
#  'sostenes cavalcante',
#  'moema gramacho',
#  'marinha raupp',
#  'jorge solla',
#  'saguas moraes',
#  'danrlei de deus hinterholz',
#  'joao fernando coutinho',
#  'enio verri',
#  'eros biondini',
#  'heitor schuch',
#  'aelton freitas',
#  'wilson filho',
#  'glauber braga',
#  'benjamin maranhao',
#  'stefano aguiar',
#  'marcos soares',
#  'rogerio peninha mendonca',
#  'siba machado',
#  'max filho',
#  'tereza cristina',
#  'eliziane gama',
#  'zeca cavalcanti',
#  'saraiva felipe',
#  'capitao augusto',
#  'jose rocha',
#  'paulo azi',
#  'vitor valim',
#  'darcisio perondi',
#  'roberto sales',
#  'vander loubet',
#  'washington reis',
#  'professora dorinha seabra rezende',
#  'marco tebaldi',
#  'sergio brito',
#  'cabucu borges',
#  'carlos marun',
#  'pedro vilela',
#  'mauricio quintella lessa',
#  'cleber verde',
#  'silvio costa',
#  'junior marreca',
#  'mendonca filho',
#  'dr. jorge silva',
#  'vanderlei macris',
#  'jessica sales',
#  'benito gama',
#  'weliton prado',
#  'joao castelo',
#  'brunny',
#  'izalci',
#  'onyx lorenzoni',
#  'diego garcia',
#  'raimundo gomes de matos',
#  'alex canziani',
#  'luiz couto',
#  'adail carneiro',
#  'alberto fraga',
#  'jhc',
#  'ze geraldo',
#  'weverton rocha',
#  'fabio sousa',
#  'clarissa garotinho',
#  'arnon bezerra',
#  'manoel junior',
#  'delegado edson moreira',
#  'joao arruda',
#  'rogerio marinho',
#  'kaio manicoba',
#  'jarbas vasconcelos',
#  'bohn gass',
#  'jose otavio germano',
#  'maria do rosario',
#  'leonardo quintao',
#  'silvio torres',
#  'newton cardoso jr',
#  'felix mendonca junior',
#  'conceicao sampaio',
#  'lucas vergilio',
#  'fernando coelho filho',
#  'alexandre serfiotis',
#  'fabio faria',
#  'cesar messias',
#  'jair bolsonaro',
#  'givaldo carimbao',
#  'guilherme mussi',
#  'alessandro molon',
#  'luiz claudio',
#  'eduardo cury',
#  'celso russomanno',
#  'flavia morais',
#  'paulo magalhaes',
#  'magda mofatto',
#  'caetano',
#  'cesar souza',
#  'zenaide maia',
#  'assis do couto',
#  'hugo motta',
#  'evair de melo',
#  'miro teixeira',
#  'paulo teixeira',
#  'valdir colatto',
#  'bruno covas',
#  'dr. joao',
#  'ze carlos',
#  'arlindo chinaglia',
#  'miguel haddad',
#  'daniel vilela',
#  'erika kokay',
#  'fernando francischini',
#  'delegado eder mauro',
#  'fabio mitidieri',
#  'gonzaga patriota',
#  'rossoni',
#  'fabio ramalho',
#  'jorge corte real',
#  'renzo braz',
#  'jose mentor',
#  'luiz carlos busato',
#  'joao derly',
#  'bonifacio de andrada',
#  'rubens pereira junior',
#  'tia eron',
#  'hermes parcianello',
#  'mauro lopes',
#  'lelo coimbra',
#  'mario negromonte jr.',
#  'silas freire',
#  'gorete pereira',
#  'marcelo aguiar']

# %%
normalized_names
# Out:
# ['GOULART',
#  'BETO FARO',
#  'RODRIGO DE CASTRO',
#  'LAERTE BESSA',
#  'MAJOR OLIMPIO',
#  'LUIS TIBE',
#  'ALIEL MACHADO',
#  'IVAN VALENTE',
#  'PEDRO CHAVES',
#  'ASSIS CARVALHO',
#  'BETINHO GOMES',
#  'CARLOS HENRIQUE GAGUIM',
#  'LUIZ CARLOS RAMOS ',
#  'JOSI NUNES',
#  'ALFREDO KAEFER',
#  'RICARDO TRIPOLI',
#  'FELIPE MAIA',
#  'LEOPOLDO MEYER',
#  'MARINALDO ROSENDO',
#  'NELSON MARQUEZELLI',
#  'DOMINGOS SAVIO',
#  'RAQUEL MUNIZ',
#  'FABIO GARCIA',
#  'VICENTINHO JUNIOR',
#  'ANDRE FUFUCA',
#  'LEO DE BRITO',
#  'ANDERSON FERREIRA',
#  'AGUINALDO RIBEIRO',
#  'EVANDRO ROMAN',
#  'DECIO LIMA',
#  'AFONSO FLORENCE',
#  'ROSANGELA GOMES',
#  'CELSO MALDANER',
#  'MARCUS VICENTE',
#  'ADELSON BARRETO',
#  'VINICIUS CARVALHO',
#  'ANTONIO IMBASSAHY',
#  'GIUSEPPE VECCI',
#  'JEAN WYLLYS',
#  'ROBERTO BRITTO',
#  'SERGIO ZVEITER',
#  'WALTER ALVES',
#  'ALTINEU CORTES',
#  'JOAO DANIEL',
#  'JONY MARCOS',
#  'MARCON',
#  'DILCEU SPERAFICO',
#  'EZEQUIEL FONSECA',
#  'TAKAYAMA',
#  'ANTONIO BULHOES',
#  'INDIO DA COSTA',
#  'VICENTINHO',
#  'AUGUSTO CARVALHO',
#  'MARCOS ABRAO',
#  'VINICIUS GURGEL',
#  'CACA LEAO',
#  'GEOVANIA DE SA',
#  'LAZARO BOTELHO',
#  'ARTHUR OLIVEIRA MAIA',
#  'SERGIO VIDIGAL',
#  'ROCHA',
#  'LEONARDO PICCIANI',
#  'EDUARDO BARBOSA',
#  'JEFFERSON CAMPOS',
#  'RONALDO FONSECA',
#  'DANILO FORTE',
#  'AFONSO MOTTA',
#  'WALDENOR PEREIRA',
#  'ATILA LINS',
#  'REMIDIO MONAI',
#  'BRUNA FURLAN',
#  'FERNANDO JORDAO',
#  'RONEY NEMER',
#  'MORONI TORGAN',
#  'CARLOS ANDRADE',
#  'PR. MARCO FELICIANO',
#  'CELSO PANSERA',
#  'JULIO CESAR',
#  'RICARDO IZAR',
#  'TADEU ALENCAR',
#  'JOAQUIM PASSARINHO',
#  'LEONARDO MONTEIRO',
#  'VALTENIR PEREIRA',
#  'CESAR HALUM',
#  'ALUISIO MENDES',
#  'ROBERTO BALESTRA',
#  'EDMAR ARRUDA',
#  'MARIA HELENA',
#  'EFRAIM FILHO',
#  'DAMINA PEREIRA',
#  'CARLOS SAMPAIO',
#  'JOAO CAMPOS',
#  'LAERCIO OLIVEIRA',
#  'CABO DACIOLO',
#  'JUTAHY JUNIOR',
#  'LUIZ CARLOS HAULY',
#  'GABRIEL GUIMARAES',
#  'HELIO LEITE',
#  'CICERO ALMEIDA',
#  'BACELAR',
#  'AUREO',
#  'MARGARIDA SALOMAO',
#  'WALDIR MARANHAO',
#  'MACEDO',
#  'HISSA ABRAHAO',
#  'ALEXANDRE BALDY',
#  'ADILTON SACHETTI',
#  'DELEGADO WALDIR',
#  'DANIEL COELHO',
#  'ALFREDO NASCIMENTO',
#  'CARLOS BEZERRA',
#  'OSMAR SERRAGLIO',
#  'MAURO MARIANI',
#  'ALEXANDRE VALLE',
#  'DAGOBERTO',
#  'ALEX MANENTE',
#  'JOSE CARLOS ALELUIA',
#  'MARX BELTRAO ',
#  'MARCO MAIA',
#  'RUBENS OTONI',
#  'CELIO SILVEIRA',
#  'PAULO MALUF',
#  'BETO ROSADO',
#  'LINDOMAR GARCON',
#  'DULCE MIRANDA',
#  'MANDETTA',
#  'EZEQUIEL TEIXEIRA',
#  'LUIZA ERUNDINA',
#  'RICARDO BARROS',
#  'ALCEU MOREIRA',
#  'ROBERTO GOES',
#  'ELMAR NASCIMENTO',
#  'PAULO FEIJO',
#  'WLADIMIR COSTA',
#  'ANIBAL GOMES',
#  'PROFESSORA MARCIVANIA',
#  'JOSE GUIMARAES',
#  'NELSON MARCHEZAN JUNIOR',
#  'BETO MANSUR',
#  'JULIO DELGADO',
#  'RONALDO CARLETTO',
#  'EVANDRO GUSSI',
#  'MARCIO ALVINO',
#  'JULIO LOPES',
#  'ANDRE FIGUEIREDO',
#  'SERGIO REIS',
#  'MILTON MONTI',
#  'GIOVANI CHERINI',
#  'PAULO FOLETTO',
#  'JAIME MARTINS',
#  'OSMAR TERRA',
#  'GIVALDO VIEIRA',
#  'SARNEY FILHO',
#  'JOSE CARLOS ARAUJO',
#  'GILBERTO NASCIMENTO',
#  'SORAYA SANTOS',
#  'BENEDITA DA SILVA',
#  'SIMONE MORGADO',
#  'TONINHO WANDSCHEER',
#  'NILTO TATTO',
#  'DANIEL ALMEIDA',
#  'FABIO REIS',
#  'JUSCELINO FILHO',
#  'RONALDO NOGUEIRA',
#  'CARLOS GOMES',
#  'PASTOR FRANKLIN',
#  'HUGO LEAL',
#  'ANTONIO BRITO',
#  'GERALDO RESENDE',
#  'CARLOS ZARATTINI',
#  'SHERIDAN',
#  'JOSUE BENGTSON',
#  'RAFAEL MOTTA',
#  'PAULO PEREIRA DA SILVA',
#  'PAULO FREIRE',
#  'DIMAS FABIANO',
#  'ESPERIDIAO AMIN',
#  'ALAN RICK',
#  'DOMINGOS NETO',
#  'JO MORAES',
#  'NILSON LEITAO',
#  'WOLNEY QUEIROZ',
#  'ARNALDO JORDY',
#  'JOSE PRIANTE',
#  'SIMAO SESSIM',
#  'HEULER CRUVINEL',
#  'ORLANDO SILVA',
#  'LUCIANA SANTOS',
#  'MARCELO BELINATI',
#  'MISAEL VARELLA',
#  'ROBERTO ALVES',
#  'PEDRO CUNHA LIMA',
#  'PADRE JOAO',
#  'SERGIO MORAES',
#  'IRACEMA PORTELLA',
#  'JOSE AIRTON CIRILO',
#  'LUCIO VIEIRA LIMA',
#  'MARCELO MATOS',
#  'JERONIMO GOERGEN',
#  'HERACLITO FORTES',
#  'GENECIAS NORONHA',
#  'LUCIANO DUCCI',
#  'RICARDO TEOBALDO ',
#  'JORGINHO MELLO',
#  'VALMIR PRASCIDELLI',
#  'JOAO GUALBERTO',
#  'JOSE NUNES',
#  'ZECA DIRCEU',
#  'MARIANA CARVALHO',
#  'TIRIRICA',
#  'DIEGO ANDRADE',
#  'MARCOS REATEGUI',
#  'AFONSO HAMM',
#  'SILAS CAMARA',
#  'ZECA DO PT',
#  'VICTOR MENDES',
#  'ABEL MESQUITA JR.',
#  'ALICE PORTUGAL',
#  'ROGERIO ROSSO',
#  'PAULO ABI-ACKEL',
#  'JANDIRA FEGHALI',
#  'DELEY',
#  'JOVAIR ARANTES',
#  'VENEZIANO VITAL DO REGO',
#  'EDUARDO BOLSONARO',
#  'LUIZ FERNANDO FARIA',
#  'CRISTIANE BRASIL',
#  'HERCULANO PASSOS',
#  'RODRIGO PACHECO',
#  'ARTHUR VIRGILIO BISNETO',
#  "CHICO D'ANGELO",
#  'CHICO ALENCAR',
#  'ARTHUR LIRA',
#  'ROMULO GOUVEIA',
#  'LEANDRE',
#  'NILSON PINTO',
#  'MARA GABRILLI',
#  'BILAC PINTO',
#  'JOAO RODRIGUES',
#  'ODELMO LEAO',
#  'LUIS CARLOS HEINZE',
#  'JORGE TADEU MUDALEN',
#  'JHONATAN DE JESUS',
#  'ULDURICO JUNIOR',
#  'LAUDIVIO CARVALHO',
#  'CARLOS MANATO',
#  'ANGELIM',
#  'POMPEO DE MATTOS',
#  'EDUARDO CUNHA',
#  'ERIVELTON SANTANA',
#  'PEDRO FERNANDES',
#  'MISSIONARIO JOSE OLIMPIO',
#  'MARCELO ARO',
#  'MOSES RODRIGUES',
#  'GIACOBO',
#  'ALEXANDRE LEITE',
#  'CHICO LOPES',
#  'JANETE CAPIBERIBE',
#  'LUIZIANNE LINS',
#  'ZE SILVA',
#  'MARCELO ALVARO ANTONIO',
#  'LUIZ SERGIO',
#  'HENRIQUE FONTANA',
#  'FLAVIANO MELO',
#  'EXPEDITO NETTO',
#  'CARLOS MELLES',
#  'LUIZ LAURO FILHO',
#  'RUBENS BUENO',
#  'RENATO MOLLING',
#  'BEBETO',
#  'ANDRE ABDON',
#  'MIGUEL LOMBARDI',
#  'NILTON CAPIXABA',
#  'LUCIO VALE',
#  'EDMILSON RODRIGUES',
#  'TENENTE LUCIO',
#  'RONALDO BENEDET',
#  'LUIZ NISHIMORI',
#  'RODRIGO MAIA',
#  'FRANCISCO FLORIANO',
#  'ADALBERTO CAVALCANTI',
#  'MARCELO CASTRO',
#  'CLAUDIO CAJADO',
#  'VALMIR ASSUNCAO',
#  'ELI CORREA FILHO',
#  'IRMAO LAZARO',
#  'BALEIA ROSSI',
#  'HILDO ROCHA',
#  'CABO SABINO',
#  'CARMEN ZANOTTO',
#  'MARIO HERINGER',
#  'ANDRE MOURA',
#  'WELLINGTON ROBERTO',
#  'IRAJA ABREU',
#  'JULIA MARINHO',
#  'PAULAO',
#  'ODORICO MONTEIRO',
#  'SERGIO SOUZA ',
#  'DAMIAO FELICIANO',
#  'ANA PERUGINI',
#  'NELSON MEURER',
#  'ANDRES SANCHEZ',
#  'FLAVINHO',
#  'ATILA LIRA',
#  'FAUSTO PINATO',
#  'ANTONIO JACOME',
#  'VICENTE CANDIDO',
#  'SUBTENENTE GONZAGA',
#  'KEIKO OTA',
#  'LINCOLN PORTELA',
#  'RODRIGO MARTINS',
#  'PASTOR EURICO',
#  'VITOR LIPPI',
#  'ARNALDO FARIA DE SA',
#  'SILAS BRASILEIRO',
#  'WADSON RIBEIRO',
#  'AUGUSTO COUTINHO ',
#  'FERNANDO MONTEIRO ',
#  'CARLOS EDUARDO CADOCA',
#  'FERNANDO MARRONI',
#  'WALNEY ROCHA',
#  'MARQUINHO MENDES',
#  'CELSO JACOB',
#  'MAURO PEREIRA',
#  'JOSE FOGACA ',
#  'ROBERTO FREIRE',
#  'ALBERTO FILHO',
#  'MAINHA',
#  'WADIH DAMOUS',
#  'PENNA',
#  'RAUL JUNGMANN',
#  'FABRICIO OLIVEIRA',
#  'VICENTE ARRUDA',
#  'ANTONIO CARLOS MENDES THAME',
#  'LOBBE NETO',
#  'DAVIDSON MAGALHAES',
#  'SANDES JUNIOR',
#  'EDINHO BEZ',
#  'WALTER IHOSHI',
#  'ADEMIR CAMILO',
#  'FERNANDO TORRES',
#  'PAUDERNEY AVELINO',
#  'ELCIONE BARBALHO',
#  'HELDER SALOMAO',
#  'RENATA ABREU',
#  'PROFESSOR VICTORIO GALLI',
#  'BETO SALAME',
#  'BRUNO ARAUJO',
#  'JOAO CARLOS BACELAR',
#  'MARCUS PESTANA',
#  'TONINHO PINHEIRO',
#  'CHRISTIANE DE SOUZA YARED',
#  'CAIO NARCIO',
#  'RONALDO LESSA',
#  'REGINALDO LOPES',
#  'LUCIO MOSQUINI',
#  'FRANCISCO CHAPADINHA',
#  'RONALDO MARTINS',
#  'EDIO LOPES',
#  'JOAO PAULO PAPA',
#  'MARCOS MONTES',
#  'SAMUEL MOREIRA',
#  'MARCIO MARINHO',
#  'LEONIDAS CRISTINO',
#  'MARCOS ROTTA',
#  'MARCELO SQUASSONI',
#  'SANDRO ALEX',
#  'PAES LANDIM',
#  'VALADARES FILHO',
#  'PEDRO UCZAI',
#  'JOZI ARAUJO',
#  'HIRAN GONCALVES',
#  'JOAO MARCELO SOUZA',
#  'PAULO PIMENTA',
#  'JOSE REINALDO',
#  'COVATTI FILHO',
#  'FELIPE BORNIER',
#  'DR. SINVAL MALHEIROS',
#  'JOSE STEDILE',
#  'MARCOS ROGERIO',
#  'OTAVIO LEITE',
#  'EDUARDO DA FONTE',
#  'ADELMO CARNEIRO LEAO',
#  'SOSTENES CAVALCANTE',
#  'MOEMA GRAMACHO',
#  'MARINHA RAUPP',
#  'JORGE SOLLA',
#  'SAGUAS MORAES',
#  'DANRLEI DE DEUS HINTERHOLZ',
#  'JOAO FERNANDO COUTINHO',
#  'ENIO VERRI',
#  'EROS BIONDINI',
#  'HEITOR SCHUCH',
#  'AELTON FREITAS',
#  'WILSON FILHO',
#  'GLAUBER BRAGA',
#  'BENJAMIN MARANHAO',
#  'STEFANO AGUIAR',
#  'MARCOS SOARES',
#  'ROGERIO PENINHA MENDONCA',
#  'SIBA MACHADO',
#  'MAX FILHO',
#  'TEREZA CRISTINA',
#  'ELIZIANE GAMA',
#  'ZECA CAVALCANTI',
#  'SARAIVA FELIPE',
#  'CAPITAO AUGUSTO',
#  'JOSE ROCHA',
#  'PAULO AZI',
#  'VITOR VALIM',
#  'DARCISIO PERONDI',
#  'ROBERTO SALES',
#  'VANDER LOUBET',
#  'WASHINGTON REIS',
#  'PROFESSORA DORINHA SEABRA REZENDE',
#  'MARCO TEBALDI',
#  'SERGIO BRITO',
#  'CABUCU BORGES',
#  'CARLOS MARUN',
#  'PEDRO VILELA',
#  'MAURICIO QUINTELLA LESSA',
#  'CLEBER VERDE',
#  'SILVIO COSTA',
#  'JUNIOR MARRECA',
#  'MENDONCA FILHO',
#  'DR. JORGE SILVA',
#  'VANDERLEI MACRIS',
#  'JESSICA SALES',
#  'BENITO GAMA',
#  'WELITON PRADO',
#  'JOAO CASTELO',
#  'BRUNNY',
#  'IZALCI',
#  'ONYX LORENZONI',
#  'DIEGO GARCIA',
#  'RAIMUNDO GOMES DE MATOS',
#  'ALEX CANZIANI',
#  'LUIZ COUTO',
#  'ADAIL CARNEIRO',
#  'ALBERTO FRAGA',
#  'JHC',
#  'ZE GERALDO',
#  'WEVERTON ROCHA',
#  'FABIO SOUSA',
#  'CLARISSA GAROTINHO',
#  'ARNON BEZERRA',
#  'MANOEL JUNIOR',
#  'DELEGADO EDSON MOREIRA',
#  'JOAO ARRUDA',
#  'ROGERIO MARINHO',
#  'KAIO MANICOBA',
#  'JARBAS VASCONCELOS',
#  'BOHN GASS',
#  'JOSE OTAVIO GERMANO',
#  'MARIA DO ROSARIO',
#  'LEONARDO QUINTAO',
#  'SILVIO TORRES',
#  'NEWTON CARDOSO JR',
#  'FELIX MENDONCA JUNIOR',
#  'CONCEICAO SAMPAIO',
#  'LUCAS VERGILIO',
#  'FERNANDO COELHO FILHO',
#  'ALEXANDRE SERFIOTIS',
#  'FABIO FARIA',
#  'CESAR MESSIAS',
#  'JAIR BOLSONARO',
#  'GIVALDO CARIMBAO',
#  'GUILHERME MUSSI',
#  'ALESSANDRO MOLON',
#  'LUIZ CLAUDIO',
#  'EDUARDO CURY',
#  'CELSO RUSSOMANNO',
#  'FLAVIA MORAIS',
#  'PAULO MAGALHAES',
#  'MAGDA MOFATTO',
#  'CAETANO',
#  'CESAR SOUZA',
#  'ZENAIDE MAIA',
#  'ASSIS DO COUTO',
#  'HUGO MOTTA',
#  'EVAIR DE MELO',
#  'MIRO TEIXEIRA',
#  'PAULO TEIXEIRA',
#  'VALDIR COLATTO',
#  'BRUNO COVAS',
#  'DR. JOAO',
#  'ZE CARLOS',
#  'ARLINDO CHINAGLIA',
#  'MIGUEL HADDAD',
#  'DANIEL VILELA',
#  'ERIKA KOKAY',
#  'FERNANDO FRANCISCHINI',
#  'DELEGADO EDER MAURO',
#  'FABIO MITIDIERI',
#  'GONZAGA PATRIOTA',
#  'ROSSONI',
#  'FABIO RAMALHO',
#  'JORGE CORTE REAL',
#  'RENZO BRAZ',
#  'JOSE MENTOR',
#  'LUIZ CARLOS BUSATO',
#  'JOAO DERLY',
#  'BONIFACIO DE ANDRADA',
#  'RUBENS PEREIRA JUNIOR',
#  'TIA ERON',
#  'HERMES PARCIANELLO',
#  'MAURO LOPES',
#  'LELO COIMBRA',
#  'MARIO NEGROMONTE JR.',
#  'SILAS FREIRE',
#  'GORETE PEREIRA',
#  'MARCELO AGUIAR']

# %%
remover_acentos('VICENTINHO JÚNIOR')
# Out:
# 'VICENTINHO JUNIOR'
