# %%
import numpy as np
import pandas as pd

# %%
deputados = pd.read_csv('../data/deputados.csv')

# %%
deputados.columns
# Out:
# Index([u'Unnamed: 0', u'ideCadastro', u'codOrcamento', u'condicao',
#        u'matricula', u'idParlamentar', u'nome', u'nomeParlamentar', u'urlFoto',
#        u'sexo', u'uf', u'partido', u'gabinete', u'anexo', u'fone', u'email',
#        u'comissoes'],
#       dtype='object')

# %%
deputados.head()
# Out:
#    Unnamed: 0  ideCadastro  codOrcamento condicao  matricula  idParlamentar  \
# 0           0       178980        3283.0  Titular        361        5830382
# 1           1       141335        2152.0  Titular         19        5830714
# 2           2       141531        2488.0  Titular        268        5830453
# 3           3       141478        2551.0  Titular        412        5830785
# 4           4       178826        3712.0  Titular        368        5830405
#
#                          nome    nomeParlamentar  \
# 0    ANTONIO GOULART DOS REIS            GOULART
# 1  JOSÉ ROBERTO OLIVEIRA FARO          BETO FARO
# 2   RODRIGO BATISTA DE CASTRO  RODRIGO DE CASTRO
# 3   LAERTE RODRIGUES DE BESSA       LAERTE BESSA
# 4        SERGIO OLIMPIO GOMES      MAJOR OLIMPIO
#
#                                              urlFoto       sexo  uf partido  \
# 0  http://www.camara.gov.br/internet/deputado/ban...  masculino  SP     PSD
# ...

# %%
deputados[deputados['ideCadastro'] == 178957]
# Out:
#      Unnamed: 0  ideCadastro  codOrcamento condicao  matricula  idParlamentar  \
# 207         207       178957        3030.0  Titular          1        5830756
#
#                               nome    nomeParlamentar  \
# 207  ABEL SALVADOR MESQUITA JUNIOR  ABEL MESQUITA JR.
#
#                                                urlFoto       sexo  uf partido  \
# 207  http://www.camara.gov.br/internet/deputado/ban...  masculino  RR     DEM
#
#      gabinete  anexo       fone                             email  \
# 207       248      4  3215-5248  dep.abelmesquitajr@camara.gov.br
#
#                                  comissoes
# 207  {u'titular': None, u'suplente': None}
